# %%
import pandas as pd
import numpy as np
import scipy.stats as stats
import statsmodels.formula.api as sm
from matplotlib import pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv ("Downloads/beatles_spotify_dataset.csv", index_col=0)
df.head ()
# Out:
#                                     name                    album  \
# 0                      Taxman - 2022 Mix  Revolver (Super Deluxe)
# 1               Eleanor Rigby - 2022 Mix  Revolver (Super Deluxe)
# 2           I'm Only Sleeping - 2022 Mix  Revolver (Super Deluxe)
# 3                 Love You To - 2022 Mix  Revolver (Super Deluxe)
# 4  Here, There And Everywhere - 2022 Mix  Revolver (Super Deluxe)
#
#   release_date  track_number                      id  \
# 0   10/28/2022             1  1u2yF3CsOvVOMP82AgP2gJ
# 1   10/28/2022             2  1Oo6F5Dn1s8hrUDUQuoCqB
# 2   10/28/2022             3  7sNSyrCw3F7qnMpl938JUZ
# 3   10/28/2022             4  0NT88kD8fIXuwBOuXlPcmx
# 4   10/28/2022             5  47gNXRKcBJxu6bOvmyUroI
#
#                                     uri  acousticness  danceability  energy  \
# 0  spotify:track:1u2yF3CsOvVOMP82AgP2gJ       0.00225         0.484   0.771
# 1  spotify:track:1Oo6F5Dn1s8hrUDUQuoCqB       0.85300         0.606   0.304
# ...

# %%
df.drop(columns=['id','uri'], inplace=True)

# %%
df.head()
# Out:
#                                     name                    album  \
# 0                      Taxman - 2022 Mix  Revolver (Super Deluxe)
# 1               Eleanor Rigby - 2022 Mix  Revolver (Super Deluxe)
# 2           I'm Only Sleeping - 2022 Mix  Revolver (Super Deluxe)
# 3                 Love You To - 2022 Mix  Revolver (Super Deluxe)
# 4  Here, There And Everywhere - 2022 Mix  Revolver (Super Deluxe)
#
#   release_date  track_number  acousticness  danceability  energy  \
# 0   10/28/2022             1       0.00225         0.484   0.771
# 1   10/28/2022             2       0.85300         0.606   0.304
# 2   10/28/2022             3       0.09440         0.559   0.479
# 3   10/28/2022             4       0.70600         0.460   0.600
# 4   10/28/2022             5       0.87000         0.345   0.304
#
#    instrumentalness  liveness  loudness  speechiness    tempo  valence  \
# 0          0.000000     0.718    -6.151       0.1300  133.603    0.679
# ...

# %%
df.head()
# Out:
#                                     name                    album  \
# 0                      Taxman - 2022 Mix  Revolver (Super Deluxe)
# 1               Eleanor Rigby - 2022 Mix  Revolver (Super Deluxe)
# 2           I'm Only Sleeping - 2022 Mix  Revolver (Super Deluxe)
# 3                 Love You To - 2022 Mix  Revolver (Super Deluxe)
# 4  Here, There And Everywhere - 2022 Mix  Revolver (Super Deluxe)
#
#   release_date  track_number  acousticness  danceability  energy  \
# 0   10/28/2022             1       0.00225         0.484   0.771
# 1   10/28/2022             2       0.85300         0.606   0.304
# 2   10/28/2022             3       0.09440         0.559   0.479
# 3   10/28/2022             4       0.70600         0.460   0.600
# 4   10/28/2022             5       0.87000         0.345   0.304
#
#    instrumentalness  liveness  loudness  speechiness    tempo  valence  \
# 0          0.000000     0.718    -6.151       0.1300  133.603    0.679
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 675 entries, 0 to 674
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              675 non-null    object
#  1   album             675 non-null    object
#  2   release_date      675 non-null    object
#  3   track_number      675 non-null    int64
#  4   acousticness      675 non-null    float64
#  5   danceability      675 non-null    float64
#  6   energy            675 non-null    float64
#  7   instrumentalness  675 non-null    float64
#  8   liveness          675 non-null    float64
#  9   loudness          675 non-null    float64
#  10  speechiness       675 non-null    float64
#  11  tempo             675 non-null    float64
#  12  valence           675 non-null    float64
#  13  popularity        675 non-null    int64
#  14  duration_ms       675 non-null    int64
# dtypes: float64(9), int64(3), object(3)
# memory usage: 84.4+ KB

# %%
df['duration'] = df['duration_ms'] // 1000
df.head()
# Out:
#                                     name                    album  \
# 0                      Taxman - 2022 Mix  Revolver (Super Deluxe)
# 1               Eleanor Rigby - 2022 Mix  Revolver (Super Deluxe)
# 2           I'm Only Sleeping - 2022 Mix  Revolver (Super Deluxe)
# 3                 Love You To - 2022 Mix  Revolver (Super Deluxe)
# 4  Here, There And Everywhere - 2022 Mix  Revolver (Super Deluxe)
#
#   release_date  track_number  acousticness  danceability  energy  \
# 0   10/28/2022             1       0.00225         0.484   0.771
# 1   10/28/2022             2       0.85300         0.606   0.304
# 2   10/28/2022             3       0.09440         0.559   0.479
# 3   10/28/2022             4       0.70600         0.460   0.600
# 4   10/28/2022             5       0.87000         0.345   0.304
#
#    instrumentalness  liveness  loudness  speechiness    tempo  valence  \
# 0          0.000000     0.718    -6.151       0.1300  133.603    0.679
# ...

# %%
df.drop(columns='duration_ms',inplace=True)
df.head()
# Out:
#                                     name                    album  \
# 0                      Taxman - 2022 Mix  Revolver (Super Deluxe)
# 1               Eleanor Rigby - 2022 Mix  Revolver (Super Deluxe)
# 2           I'm Only Sleeping - 2022 Mix  Revolver (Super Deluxe)
# 3                 Love You To - 2022 Mix  Revolver (Super Deluxe)
# 4  Here, There And Everywhere - 2022 Mix  Revolver (Super Deluxe)
#
#   release_date  track_number  acousticness  danceability  energy  \
# 0   10/28/2022             1       0.00225         0.484   0.771
# 1   10/28/2022             2       0.85300         0.606   0.304
# 2   10/28/2022             3       0.09440         0.559   0.479
# 3   10/28/2022             4       0.70600         0.460   0.600
# 4   10/28/2022             5       0.87000         0.345   0.304
#
#    instrumentalness  liveness  loudness  speechiness    tempo  valence  \
# 0          0.000000     0.718    -6.151       0.1300  133.603    0.679
# ...

# %%
df.drop(columns='track_number',inplace=True)
df.head()
# Out:
#                                     name                    album  \
# 0                      Taxman - 2022 Mix  Revolver (Super Deluxe)
# 1               Eleanor Rigby - 2022 Mix  Revolver (Super Deluxe)
# 2           I'm Only Sleeping - 2022 Mix  Revolver (Super Deluxe)
# 3                 Love You To - 2022 Mix  Revolver (Super Deluxe)
# 4  Here, There And Everywhere - 2022 Mix  Revolver (Super Deluxe)
#
#   release_date  acousticness  danceability  energy  instrumentalness  \
# 0   10/28/2022       0.00225         0.484   0.771          0.000000
# 1   10/28/2022       0.85300         0.606   0.304          0.000000
# 2   10/28/2022       0.09440         0.559   0.479          0.000000
# 3   10/28/2022       0.70600         0.460   0.600          0.000043
# 4   10/28/2022       0.87000         0.345   0.304          0.000031
#
#    liveness  loudness  speechiness    tempo  valence  popularity  duration
# 0     0.718    -6.151       0.1300  133.603    0.679          57       158
# ...

# %%
df.describe()
# Out:
#        acousticness  danceability      energy  instrumentalness    liveness  \
# count    675.000000    675.000000  675.000000        675.000000  675.000000
# mean       0.405256      0.532309    0.522586          0.068203    0.251490
# std        0.314677      0.151987    0.205235          0.194286    0.210163
# min        0.000023      0.000000    0.012400          0.000000    0.037100
# 25%        0.097300      0.424000    0.372500          0.000000    0.107000
# 50%        0.352000      0.534000    0.530000          0.000010    0.164000
# 75%        0.696500      0.634500    0.668000          0.001690    0.320000
# max        0.994000      0.915000    0.969000          0.942000    0.948000
#
#          loudness  speechiness       tempo     valence  popularity    duration
# count  675.000000   675.000000  675.000000  675.000000  675.000000  675.000000
# mean   -10.416490     0.090423  120.405055    0.607886   38.521481  165.585185
# ...

# %%
df['rating'] = 1 - (df['popularity'] - 1)/80

# %%
df.head()
# Out:
#                                     name                    album  \
# 0                      Taxman - 2022 Mix  Revolver (Super Deluxe)
# 1               Eleanor Rigby - 2022 Mix  Revolver (Super Deluxe)
# 2           I'm Only Sleeping - 2022 Mix  Revolver (Super Deluxe)
# 3                 Love You To - 2022 Mix  Revolver (Super Deluxe)
# 4  Here, There And Everywhere - 2022 Mix  Revolver (Super Deluxe)
#
#   release_date  acousticness  danceability  energy  instrumentalness  \
# 0   10/28/2022       0.00225         0.484   0.771          0.000000
# 1   10/28/2022       0.85300         0.606   0.304          0.000000
# 2   10/28/2022       0.09440         0.559   0.479          0.000000
# 3   10/28/2022       0.70600         0.460   0.600          0.000043
# 4   10/28/2022       0.87000         0.345   0.304          0.000031
#
#    liveness  loudness  speechiness    tempo  valence  popularity  duration  \
# ...

# %%
df.corr()
# Out:
#                   acousticness  danceability    energy  instrumentalness  \
# acousticness          1.000000      0.091278 -0.620794          0.020193
# danceability          0.091278      1.000000 -0.097027         -0.080194
# energy               -0.620794     -0.097027  1.000000         -0.053633
# instrumentalness      0.020193     -0.080194 -0.053633          1.000000
# liveness             -0.116593     -0.177667  0.269390          0.000857
# loudness             -0.532298     -0.111873  0.721105         -0.098127
# speechiness           0.295328      0.223685 -0.269710         -0.068302
# tempo                -0.052994     -0.100815  0.142967          0.002839
# valence              -0.168972      0.355266  0.382475         -0.261725
# popularity           -0.227347     -0.122818  0.172524         -0.022905
# duration             -0.151473     -0.268672  0.024772         -0.000200
# rating                0.227347      0.122818 -0.172524          0.022905
#
# ...
